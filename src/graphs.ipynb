# %%
# Jupyter dirty hack to import from a given folder
import os
import sys

PATH: str = "/home/emaballarin/repositories/excitorch/src"
os.chdir(PATH)
sys.path.append(PATH)

# %%
from utils.plotting import easy_mkplot

# %%
SAVESWITCH: bool = True
SAVEREVECT: bool = True

# %%
# Color palettes
petroff_2021 = ["#717581", "#bd1f01", "#ffa90e", "#3f90da", "#832db6", "#e76300"]
col_o = [
    "#d1624d",
    petroff_2021[1],
    "#841601",
    "#4c0c00",
]  # Shades of `petroff_2021[1]`
col_u = [petroff_2021[0], "#4f525a", "#2d2f34"]  # Shades of `petroff_2021[0]`
fmt_u = ["-", "-.", "--", ":"]

# %%
# Duplicated constants (labels)
PORTS = "Prob. of reaching the sink"
PRON = "Prob. Ratio (opt./non-opt.)"

# %%
easy_mkplot(
    curvepaths=(
        "graphs/F1E1_NN_driving_punoptim_final.pth",
        "graphs/F1E1_NN_driving_poptim_final.pth",
        "graphs/F1E2_NN_coupling_poptim_final.pth",
        "graphs/F1E3_NN_energy_poptim_final.pth",
    ),
    curvenames=(
        "Unopt.",
        "Opt. Driv. R=1",
        "Opt. Coupling",
        "Opt. Energy",
    ),
    ratios=False,
    title="",
    figname="F01",
    ystr=PORTS,
    save=SAVESWITCH,
    colors=petroff_2021,
    fmt=fmt_u,
)

# %%
"""
easy_mkplot(
    curvepaths=(
        "graphs/F1E1_NN_driving_punoptim_final.pth",
        "graphs/F1E1_NN_driving_poptim_final.pth",
        "graphs/F1E2_NN_coupling_poptim_final.pth",
        "graphs/F1E3_NN_energy_poptim_final.pth",
    ),
    curvenames=(
        "Unopt.",
        "Opt. Driv. R=1",
        "Opt. Coupling",
        "Opt. Energy",
    ),
    ratios=False,
    #title="NN system (N=4), at resonance",
    title="",
    figname="F01_inset",
    ystr=PORTS,
    save=SAVESWITCH,
    colors=petroff_2021,
    fmt=fmt_u,
    nolegend=True,
    inset=(-5000,None)
)
"""
# Out:
# '\neasy_mkplot(\n    curvepaths=(\n        "graphs/F1E1_NN_driving_punoptim_final.pth",\n        "graphs/F1E1_NN_driving_poptim_final.pth",\n        "graphs/F1E2_NN_coupling_poptim_final.pth",\n        "graphs/F1E3_NN_energy_poptim_final.pth",\n    ),\n    curvenames=(\n        "Unopt.",\n        "Opt. Driv. R=1",\n        "Opt. Coupling",\n        "Opt. Energy",\n    ),\n    ratios=False,\n    #title="NN system (N=4), at resonance",\n    title="",\n    figname="F01_inset",\n    ystr=PORTS,\n    save=SAVESWITCH,\n    colors=petroff_2021,\n    fmt=fmt_u,\n    nolegend=True,\n    inset=(-5000,None)\n)\n'

# %%
easy_mkplot(
    curvepaths=(
        "graphs/F2E1_NN_driving_punoptim_final.pth",
        "graphs/F2E1_NN_driving_poptim_final.pth",
        "graphs/F2E2_NN_coupling_poptim_final.pth",
        "graphs/F2E3_NN_energy_poptim_final.pth",
    ),
    curvenames=(
        "Unopt.",
        "Opt. Driv. R=1",
        "Opt. Coupling",
        "Opt. Energy",
    ),
    ratios=False,
    title="",
    figname="F02A",
    ystr=PORTS,
    save=SAVESWITCH,
    colors=petroff_2021,
    fmt=fmt_u,
)

# %%
easy_mkplot(
    curvepaths=(
        "graphs/F2E1_NN_driving_punoptim_final.pth",
        "graphs/F2E1_NN_driving_poptim_final.pth",
        "graphs/F2E2_NN_coupling_poptim_final.pth",
        "graphs/F2E3_NN_energy_poptim_final.pth",
    ),
    curvenames=(
        "Unopt.",
        "Opt. Driv. R=1",
        "Opt. Coupling",
        "Opt. Energy",
    ),
    ratios=True,
    title="",
    figname="F02B",
    ystr=PRON,
    save=SAVESWITCH,
    colors=petroff_2021[1:],
    fmt=fmt_u[1:],
)

# %%
easy_mkplot(
    curvepaths=(
        "graphs/F2E1_NN_driving_punoptim_final.pth",
        "graphs/F2E1_NN_driving_poptim_final.pth",
        "graphs/F3E2_NN_driving_poptim_final.pth",
        "graphs/F3E3_NN_driving_poptim_final.pth",
    ),
    curvenames=(
        "Unopt.",
        "Opt. Driv. R=1",
        "Opt. Driv. R=2",
        "Opt. Driv. R=7",
    ),
    ratios=False,
    title="",
    figname="F03",
    ystr=PORTS,
    save=SAVESWITCH,
    colors=[petroff_2021[0]] + col_o[1:],
    fmt=fmt_u,
)

# %%
if SAVEREVECT:
    easy_mkplot(
        curvepaths=(
            "graphs/F2E1_NN_driving_punoptim_final.pth",
            "graphs/F2E1_NN_driving_poptim_final.pth",
            "graphs/F4E1_NN_driving_punoptim_final.pth",
            "graphs/F4E1_NN_driving_poptim_final.pth",
            "graphs/F4E4_NN_driving_punoptim_final.pth",
            "graphs/F4E4_NN_driving_poptim_final.pth",
        ),
        curvenames=(
            "Unopt. N=4",
            "Opt. Driv. N=4, R=1",
            "Unopt. N=6",
            "Opt. Driv. N=6, R=1",
            "Unopt. N=8",
            "Opt. Driv. N=8, R=1",
        ),
        ratios=False,
        title="",
        figname="F04",
        ystr=PORTS,
        save=SAVESWITCH,
        colors=(col_u[0], col_o[1:][0], col_u[1], col_o[1:][1], col_u[2], col_o[1:][2]),
        fmt=(fmt_u[1], fmt_u[1], fmt_u[2], fmt_u[2], fmt_u[3], fmt_u[3]),
        nolegend=True,
    )

# %%
easy_mkplot(
    curvepaths=(
        "graphs/F5E1_NN_driving_punoptim_final.pth",
        "graphs/F5E1_NN_driving_poptim_final.pth",
        "graphs/F5E2_NN_coupling_poptim_final.pth",
        "graphs/F5E3_NN_energy_poptim_final.pth",
    ),
    curvenames=(
        "Unopt.",
        "Opt. Driv. R=1",
        "Opt. Coupling",
        "Opt. Energy",
    ),
    ratios=False,
    title="",
    figname="F09",
    ystr=PORTS,
    save=SAVESWITCH,
    colors=petroff_2021,
    fmt=fmt_u,
)

# %%
if SAVEREVECT:
    easy_mkplot(
        curvepaths=(
            "graphs/F2E1_NN_driving_punoptim_final.pth",
            "graphs/F2E1_NN_driving_poptim_final.pth",
            "graphs/F6E3_NN_driving_punoptim_final.pth",
            "graphs/F6E3_NN_driving_poptim_final.pth",
            "graphs/F6E4_NN_driving_punoptim_final.pth",
            "graphs/F6E4_NN_driving_poptim_final.pth",
        ),
        curvenames=(
            "Unopt. $\lambda_N$=0.1",
            "Opt. Driv. $\lambda_N$=0.1, R=1",
            "Unopt. $\lambda_N$=10",
            "Opt. Driv. $\lambda_N$=10, R=1",
            "Unopt. $\lambda_N$=100",
            "Opt. Driv. $\lambda_N$=100, R=1",
        ),
        ratios=False,
        title="",
        figname="F10A",
        ystr=PORTS,
        save=SAVESWITCH,
        colors=(col_u[0], col_o[1:][0], col_u[1], col_o[1:][1], col_u[2], col_o[1:][2]),
        fmt=(fmt_u[1], fmt_u[1], fmt_u[2], fmt_u[2], fmt_u[3], fmt_u[3]),
        nolegend=True,
    )
# Out:
# <>:14: SyntaxWarning: invalid escape sequence '\l'
# <>:15: SyntaxWarning: invalid escape sequence '\l'
# <>:16: SyntaxWarning: invalid escape sequence '\l'
# <>:17: SyntaxWarning: invalid escape sequence '\l'
# <>:18: SyntaxWarning: invalid escape sequence '\l'
# <>:19: SyntaxWarning: invalid escape sequence '\l'
# <>:14: SyntaxWarning: invalid escape sequence '\l'
# <>:15: SyntaxWarning: invalid escape sequence '\l'
# <>:16: SyntaxWarning: invalid escape sequence '\l'
# <>:17: SyntaxWarning: invalid escape sequence '\l'
# <>:18: SyntaxWarning: invalid escape sequence '\l'
# <>:19: SyntaxWarning: invalid escape sequence '\l'
# /tmp/ipykernel_320522/2099138685.py:14: SyntaxWarning: invalid escape sequence '\l'
#   "Unopt. $\lambda_N$=0.1",
# /tmp/ipykernel_320522/2099138685.py:15: SyntaxWarning: invalid escape sequence '\l'
#   "Opt. Driv. $\lambda_N$=0.1, R=1",
# /tmp/ipykernel_320522/2099138685.py:16: SyntaxWarning: invalid escape sequence '\l'
#   "Unopt. $\lambda_N$=10",
# ...

# %%
easy_mkplot(
    curvepaths=(
        "graphs/F2E1_NN_driving_punoptim_final.pth",
        "graphs/F2E1_NN_driving_poptim_final.pth",
        "graphs/F6E3_NN_driving_punoptim_final.pth",
        "graphs/F6E3_NN_driving_poptim_final.pth",
        "graphs/F6E4_NN_driving_punoptim_final.pth",
        "graphs/F6E4_NN_driving_poptim_final.pth",
    ),
    curvenames=(
        "Unopt. $\lambda_N$=0.1",
        "Opt. Driv. $\lambda_N$=0.1",
        "Unopt. $\lambda_N$=10",
        "Opt. Driv. $\lambda_N$=1",
        "Unopt. $\lambda_N$=100",
        "Opt. Driv. $\lambda_N$=100",
    ),
    ratios=True,
    title="",
    figname="F10B",
    ystr=PRON,
    save=SAVESWITCH,
    colors=col_o[1:],
    fmt=fmt_u[1:],
)
# Out:
# <>:13: SyntaxWarning: invalid escape sequence '\l'
# <>:14: SyntaxWarning: invalid escape sequence '\l'
# <>:15: SyntaxWarning: invalid escape sequence '\l'
# <>:16: SyntaxWarning: invalid escape sequence '\l'
# <>:17: SyntaxWarning: invalid escape sequence '\l'
# <>:18: SyntaxWarning: invalid escape sequence '\l'
# <>:13: SyntaxWarning: invalid escape sequence '\l'
# <>:14: SyntaxWarning: invalid escape sequence '\l'
# <>:15: SyntaxWarning: invalid escape sequence '\l'
# <>:16: SyntaxWarning: invalid escape sequence '\l'
# <>:17: SyntaxWarning: invalid escape sequence '\l'
# <>:18: SyntaxWarning: invalid escape sequence '\l'
# /tmp/ipykernel_320522/1045629222.py:13: SyntaxWarning: invalid escape sequence '\l'
#   "Unopt. $\lambda_N$=0.1",
# /tmp/ipykernel_320522/1045629222.py:14: SyntaxWarning: invalid escape sequence '\l'
#   "Opt. Driv. $\lambda_N$=0.1",
# /tmp/ipykernel_320522/1045629222.py:15: SyntaxWarning: invalid escape sequence '\l'
#   "Unopt. $\lambda_N$=10",
# ...

# %%
easy_mkplot(
    curvepaths=(
        "graphs/F8E1_star_driving_punoptim_final.pth",
        "graphs/F7E2_star_driving_poptim_final.pth",
        "graphs/F8E1_star_driving_poptim_final.pth",
        "graphs/F7E3_star_driving_poptim_final.pth",
    ),
    curvenames=(
        "Unopt.",
        "Opt. Driv. R=1",
        "Opt. Driv. R=2",
        "Opt. Driv. R=7",
    ),
    ratios=False,
    title="",
    figname="F05",
    ystr=PORTS,
    save=SAVESWITCH,
    colors=[petroff_2021[0]] + col_o[:-1],
    fmt=(fmt_u[0], fmt_u[2], fmt_u[1], fmt_u[-1]),
)

# %%
easy_mkplot(
    curvepaths=(
        "graphs/F8E1_star_driving_punoptim_final.pth",
        "graphs/F8E1_star_driving_poptim_final.pth",
        "graphs/F8E2_star_coupling_poptim_final.pth",
        "graphs/F8E3_star_energy_poptim_final.pth",
    ),
    curvenames=(
        "Unopt.",
        "Opt. Driv. R=2",
        "Opt. Coupling",
        "Opt. Energy",
    ),
    ratios=False,
    title="",
    figname="F06A",
    ystr=PORTS,
    save=SAVESWITCH,
    colors=petroff_2021,
    fmt=fmt_u,
)

# %%
easy_mkplot(
    curvepaths=(
        "graphs/F8E1_star_driving_punoptim_final.pth",
        "graphs/F8E1_star_driving_poptim_final.pth",
        "graphs/F8E2_star_coupling_poptim_final.pth",
        "graphs/F8E3_star_energy_poptim_final.pth",
    ),
    curvenames=(
        "Unopt.",
        "Opt. Driv. R=2",
        "Opt. Coupling",
        "Opt. Energy",
    ),
    ratios=True,
    title="",
    figname="F06B",
    ystr=PRON,
    save=SAVESWITCH,
    colors=petroff_2021[1:],
    fmt=fmt_u[1:],
)

# %%
easy_mkplot(
    curvepaths=(
        "graphs/F10E1_FMO_driving_punoptim_final.pth",
        "graphs/F9E1_FMO_driving_poptim_final.pth",
        "graphs/F10E1_FMO_driving_poptim_final.pth",
        "graphs/F9E3_FMO_driving_poptim_final.pth",
    ),
    curvenames=(
        "Unopt.",
        "Opt. Driv. R=1",
        "Opt. Driv. R=2",
        "Opt. Driv. R=7",
    ),
    ratios=False,
    title="",
    figname="F07",
    ystr=PORTS,
    save=SAVESWITCH,
    colors=[petroff_2021[0]] + col_o[:-1],
    fmt=(fmt_u[0], fmt_u[2], fmt_u[1], fmt_u[-1]),
)

# %%
easy_mkplot(
    curvepaths=(
        "graphs/F10E1_FMO_driving_punoptim_final.pth",
        "graphs/F10E1_FMO_driving_poptim_final.pth",
        "graphs/F10E2_FMO_coupling_poptim_final.pth",
        "graphs/F10E3_FMO_energy_poptim_final.pth",
    ),
    curvenames=(
        "Unopt.",
        "Opt. Driv. R=2",
        "Opt. Coupling",
        "Opt. Energy",
    ),
    ratios=False,
    title="",
    figname="F08A",
    ystr=PORTS,
    save=SAVESWITCH,
    colors=petroff_2021,
    fmt=fmt_u,
)

# %%
easy_mkplot(
    curvepaths=(
        "graphs/F10E1_FMO_driving_punoptim_final.pth",
        "graphs/F10E1_FMO_driving_poptim_final.pth",
        "graphs/F10E2_FMO_coupling_poptim_final.pth",
        "graphs/F10E3_FMO_energy_poptim_final.pth",
    ),
    curvenames=(
        "Unopt.",
        "Opt. Driv. R=2",
        "Opt. Coupling",
        "Opt. Energy",
    ),
    ratios=True,
    title="",
    figname="F08B",
    ystr=PRON,
    save=SAVESWITCH,
    colors=petroff_2021[1:],
    fmt=fmt_u[1:],
)
